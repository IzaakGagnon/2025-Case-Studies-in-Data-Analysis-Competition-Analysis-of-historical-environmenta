# %% [markdown]
# <a href="https://colab.research.google.com/github/IzaakGagnon/SSC2025_Data_Analysis_Competiton-Topological_Approach_to_Identifying_Hypoxic_Regions/blob/main/pre_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Step 1 Read in the data
#
# HD5 has 1/17th the read and write time of csv, since the data size is on the order of 10 million points, these gains are worth while.
#
# First we read in the data files as csv, convert them each to h5, and then combine them both as h5.
#
# # Instructions
# Set dataDir to the directory containing the glider files. If the h5 files already exist there, they wont be regenerated.

# %% [markdown]
# ### Set True if using Collab - otherwise False uses the raw directory

# %%
using_colab = True

# %% [markdown]
# ### Control binning size

# %%
numbins = int(100)

# %% [markdown]
# ### Collection of necessary imports

# %%
# !pip install ripser
# !pip install persim
# !pip install networkx
# !pip install scikit-learn
# !pip install matplotlib
# !pip install tables

import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shutil
import networkx as nx
from ripser import ripser
from persim import plot_diagrams
from scipy.spatial.distance import pdist, squareform
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
# Out:
# Requirement already satisfied: ripser in /usr/local/lib/python3.11/dist-packages (0.6.12)
# Requirement already satisfied: Cython in /usr/local/lib/python3.11/dist-packages (from ripser) (3.1.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ripser) (2.0.2)
# Requirement already satisfied: persim in /usr/local/lib/python3.11/dist-packages (from ripser) (0.3.8)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from ripser) (1.15.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from ripser) (1.6.1)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from persim->ripser) (1.2.18)
# Requirement already satisfied: hopcroftkarp in /usr/local/lib/python3.11/dist-packages (from persim->ripser) (1.2.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from persim->ripser) (1.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from persim->ripser) (3.10.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->ripser) (3.6.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->persim->ripser) (1.17.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim->ripser) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim->ripser) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim->ripser) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim->ripser) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim->ripser) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim->ripser) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim->ripser) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim->ripser) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->persim->ripser) (1.17.0)
# Requirement already satisfied: persim in /usr/local/lib/python3.11/dist-packages (0.3.8)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from persim) (1.2.18)
# Requirement already satisfied: hopcroftkarp in /usr/local/lib/python3.11/dist-packages (from persim) (1.2.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from persim) (1.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from persim) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from persim) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from persim) (1.6.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->persim) (1.17.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->persim) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->persim) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->persim) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->persim) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (3.4.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: tables in /usr/local/lib/python3.11/dist-packages (3.10.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from tables) (2.0.2)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.11/dist-packages (from tables) (2.10.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tables) (25.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from tables) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from tables) (3.3.4)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from tables) (4.13.2)
# Requirement already satisfied: ndindex in /usr/local/lib/python3.11/dist-packages (from blosc2>=2.3.0->tables) (1.10.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.11/dist-packages (from blosc2>=2.3.0->tables) (1.1.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from blosc2>=2.3.0->tables) (4.3.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from blosc2>=2.3.0->tables) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->blosc2>=2.3.0->tables) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->blosc2>=2.3.0->tables) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->blosc2>=2.3.0->tables) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->blosc2>=2.3.0->tables) (2025.4.26)

# %% [markdown]
# ### Set the directory where the binned data will be stored

# %%
if using_colab:
    # Mount Google Drive in Colab
    from google.colab import drive
    drive.mount('/content/drive')
    # Set your data directory to the correct folder in your Google Drive
    data_dir = '/content/drive/MyDrive/Glider data'
else:
    # Set your local data directory path
    data_dir = 'D:/Glider_data/data/raws'
file_count = sum(1 for entry in os.listdir(data_dir)
                 if os.path.isfile(os.path.join(data_dir, entry)))
print("Number of files:", file_count)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Number of files: 63

# %% [markdown]
# ### 1) Store the data into chunks to be cleaned, then convert to a single data file with extension .h5 for faster processing

# %%
# ---------------------------
# Step 1: Convert CSV files to HDF5 files
# ---------------------------


# Define data types and chunk size for CSV reading.
dtypes = {
    "longitude": "float32",
    "latitude": "float32",
    "depth": "float32",
    "time": "str",  # Keep as string if date parsing is not required immediately
    "salinity": "float32",
    "density": "float32",
    "temperature": "float32"
}

chunksize = 10**6

def regularize_chunk(chunk):
    """
    Rename columns as needed, convert numeric columns to float32,
    and remove rows where oxygen is not positive.
    """
    col_mapping = {
        "sea_water_temperature": "temperature",
        "sea_water_practical_salinity": "salinity",
        "sea_water_density": "density",
        "micromoles_of_oxygen_per_unit_mass_in_sea_water": "oxygen"
    }

    # Rename columns
    chunk.rename(columns=col_mapping, inplace=True)

    # Converic numeric values to type float32
    for col in ["latitude", "longitude", "depth", "temperature", "salinity", "density", "oxygen"]:
        if col in chunk.columns:
            chunk[col] = pd.to_numeric(chunk[col], errors='coerce').astype("float32")

    # Remove erroneous data
    if "oxygen" in chunk.columns:
        chunk = chunk[chunk["oxygen"] > 0]
    return chunk


csv_files = glob.glob(os.path.join(data_dir, "*.csv"))

# Processing only .csv files, use the chunks to convert to .h5
for csv_file in csv_files:
    # Skip the current iteration if not filetype .csv
    if not csv_file.lower().endswith('.csv'):
        continue

    # Use the same name of the .csv file to make the .h5 file
    base_name = os.path.splitext(os.path.basename(csv_file))[0]
    hdf_file = os.path.join(data_dir, base_name + ".h5")

    # Skip already processed files
    if os.path.exists(hdf_file):
        print(f"Skipping conversion; {hdf_file} already exists.")
        continue
    print(f"Converting {csv_file} to {hdf_file}...")

    # Convert using chunks
    with pd.HDFStore(hdf_file, mode='w') as store:
        for i, chunk in enumerate(pd.read_csv(csv_file, dtype=dtypes, chunksize=chunksize, low_memory=False)):
            chunk = regularize_chunk(chunk)
            store.append('data', chunk, format='table', data_columns=True)
            print(f"  Processed chunk {i} for {csv_file}")
    print(f"Conversion complete for {csv_file}")


# ---------------------------
# Step 2: Clean the specific HDF5 file
# ---------------------------
specific_orig = os.path.join(data_dir, "cabot_20210706_135_delayed_corrected_v4.h5")
specific_fixed = os.path.join(data_dir, "fixed_cabot_20210706_135_delayed_corrected_v4.h5")
if os.path.exists(specific_orig):
    print(f"\nCleaning specific file: {specific_orig}")
    df_specific = pd.read_hdf(specific_orig, key='data')
    initial_count = len(df_specific)

    # Remove rows where density is between 1023.11 and 1023.13 (inclusive)
    df_specific_clean = df_specific[~((df_specific['density'] >= 1023.11) & (df_specific['density'] <= 1023.13))].copy()
    final_count = len(df_specific_clean)
    removed_count = initial_count - final_count
    print(f"Removed {removed_count} data points (from {initial_count} total rows) in the specific file.")

    # Save the cleaned data as a fixed version.
    df_specific_clean.to_hdf(specific_fixed, key='data', mode='w')
    print(f"Cleaned file saved as: {specific_fixed}")

    # Plot Oxygen vs. Density for the fixed file.
    plt.figure(figsize=(10, 6))
    plt.scatter(df_specific_clean['density'], df_specific_clean['oxygen'], s=1, alpha=0.5)
    plt.xlabel("Density")
    plt.ylabel("Oxygen")
    plt.title("Oxygen vs Density (Fixed Specific File)")
    plt.show()
else:
    print(f"Specific file {specific_orig} not found. Skipping cleaning step.")

# ---------------------------
# Step 3: Combine all HDF5 files into one
# ---------------------------
combined_hdf = os.path.join(data_dir, "glider_data.h5")
h5_files = glob.glob(os.path.join(data_dir, "*.h5"))

# If the fixed version exists, exclude the original specific file.
if os.path.exists(specific_fixed):
    h5_files = [f for f in h5_files if os.path.basename(f) != "cabot_20210706_135_delayed_corrected_v4.h5"]
    if specific_fixed not in h5_files:
        h5_files.append(specific_fixed)

print("\nCombining the following HDF5 files:")
for f in h5_files:
    print(f)

# Read each HDF5 file and combine the data.
df_list = []
for h5_file in h5_files:
    try:
        df_temp = pd.read_hdf(h5_file, key='data')
        df_list.append(df_temp)
        print(f"Loaded {len(df_temp)} rows from {h5_file}")
    except Exception as e:
        print(f"Error reading {h5_file}: {e}")

if df_list:
    df_combined = pd.concat(df_list, ignore_index=True)
    df_combined.to_hdf(combined_hdf, key='data', mode='w')
    print(f"\nCombined HDF5 file saved to: {combined_hdf}")
    print("Head of combined data:")
    print(df_combined.head())
else:
    print("No data to combine.")
# Out:
# Skipping conversion; /content/drive/MyDrive/Glider data/scotia_20181113_95_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/shad_20230601_168_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/sambro_20210705_134_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/scotia_20190605_100_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/scotia_20220421_150_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/cabot_20220727_158_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/fundy_20190604_99_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/cabot_20210706_135_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/scotia_20180720_87_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/peggy_20230417_167_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/fundy_20230726_175_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/peggy_20220421_151_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/cabot_20220603_155_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/cabot_20200717_114_delayed_corrected_v4.h5 already exists.
# Skipping conversion; /content/drive/MyDrive/Glider data/scotia_20210719_136_delayed_corrected_v4.h5 already exists.
#
# Cleaning specific file: /content/drive/MyDrive/Glider data/cabot_20210706_135_delayed_corrected_v4.h5
# Removed 3012 data points (from 1616488 total rows) in the specific file.
# Cleaned file saved as: /content/drive/MyDrive/Glider data/fixed_cabot_20210706_135_delayed_corrected_v4.h5
# Combining the following HDF5 files:
# /content/drive/MyDrive/Glider data/scotia_20181113_95_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/shad_20230601_168_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/sambro_20210705_134_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/scotia_20190605_100_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/scotia_20220421_150_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/cabot_20220727_158_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/fundy_20190604_99_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/scotia_20180720_87_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/peggy_20230417_167_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/fundy_20230726_175_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/peggy_20220421_151_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/cabot_20220603_155_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/cabot_20200717_114_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/scotia_20210719_136_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/fixed_cabot_20210706_135_delayed_corrected_v4.h5
# /content/drive/MyDrive/Glider data/glider_data.h5
# /content/drive/MyDrive/Glider data/component_0.h5
# /content/drive/MyDrive/Glider data/component_3.h5
# /content/drive/MyDrive/Glider data/component_1.h5
# /content/drive/MyDrive/Glider data/component_4.h5
# /content/drive/MyDrive/Glider data/component_2.h5
# /content/drive/MyDrive/Glider data/component_6.h5
# /content/drive/MyDrive/Glider data/component_5.h5
# /content/drive/MyDrive/Glider data/component_7.h5
# /content/drive/MyDrive/Glider data/component_9.h5
# /content/drive/MyDrive/Glider data/component_10.h5
# /content/drive/MyDrive/Glider data/component_8.h5
# /content/drive/MyDrive/Glider data/component_12.h5
# /content/drive/MyDrive/Glider data/component_13.h5
# /content/drive/MyDrive/Glider data/component_11.h5
# /content/drive/MyDrive/Glider data/component_17.h5
# /content/drive/MyDrive/Glider data/component_15.h5
# /content/drive/MyDrive/Glider data/component_14.h5
# /content/drive/MyDrive/Glider data/component_16.h5
# /content/drive/MyDrive/Glider data/component_20.h5
# /content/drive/MyDrive/Glider data/component_18.h5
# /content/drive/MyDrive/Glider data/component_19.h5
# /content/drive/MyDrive/Glider data/component_22.h5
# /content/drive/MyDrive/Glider data/component_21.h5
# /content/drive/MyDrive/Glider data/component_24.h5
# /content/drive/MyDrive/Glider data/component_25.h5
# /content/drive/MyDrive/Glider data/component_23.h5
# /content/drive/MyDrive/Glider data/component_27.h5
# /content/drive/MyDrive/Glider data/component_26.h5
# /content/drive/MyDrive/Glider data/component_30.h5
# /content/drive/MyDrive/Glider data/component_29.h5
# /content/drive/MyDrive/Glider data/component_28.h5
# Loaded 368411 rows from /content/drive/MyDrive/Glider data/scotia_20181113_95_delayed_corrected_v4.h5
# Loaded 495131 rows from /content/drive/MyDrive/Glider data/shad_20230601_168_delayed_corrected_v4.h5
# Loaded 378473 rows from /content/drive/MyDrive/Glider data/sambro_20210705_134_delayed_corrected_v4.h5
# Loaded 797256 rows from /content/drive/MyDrive/Glider data/scotia_20190605_100_delayed_corrected_v4.h5
# Loaded 935568 rows from /content/drive/MyDrive/Glider data/scotia_20220421_150_delayed_corrected_v4.h5
# Loaded 760518 rows from /content/drive/MyDrive/Glider data/cabot_20220727_158_delayed_corrected_v4.h5
# Loaded 45629 rows from /content/drive/MyDrive/Glider data/fundy_20190604_99_delayed_corrected_v4.h5
# Loaded 321605 rows from /content/drive/MyDrive/Glider data/scotia_20180720_87_delayed_corrected_v4.h5
# Loaded 1126714 rows from /content/drive/MyDrive/Glider data/peggy_20230417_167_delayed_corrected_v4.h5
# Loaded 1610868 rows from /content/drive/MyDrive/Glider data/fundy_20230726_175_delayed_corrected_v4.h5
# Loaded 1232478 rows from /content/drive/MyDrive/Glider data/peggy_20220421_151_delayed_corrected_v4.h5
# Loaded 349146 rows from /content/drive/MyDrive/Glider data/cabot_20220603_155_delayed_corrected_v4.h5
# Loaded 1014143 rows from /content/drive/MyDrive/Glider data/cabot_20200717_114_delayed_corrected_v4.h5
# Loaded 966523 rows from /content/drive/MyDrive/Glider data/scotia_20210719_136_delayed_corrected_v4.h5
# Loaded 1613476 rows from /content/drive/MyDrive/Glider data/fixed_cabot_20210706_135_delayed_corrected_v4.h5
# Loaded 24031881 rows from /content/drive/MyDrive/Glider data/glider_data.h5
# Error reading /content/drive/MyDrive/Glider data/component_0.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_3.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_1.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_4.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_2.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_6.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_5.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_7.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_9.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_10.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_8.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_12.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_13.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_11.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_17.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_15.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_14.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_16.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_20.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_18.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_19.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_22.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_21.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_24.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_25.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_23.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_27.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_26.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_30.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_29.h5: 'No object named data in the file'
# Error reading /content/drive/MyDrive/Glider data/component_28.h5: 'No object named data in the file'
#
# Combined HDF5 file saved to: /content/drive/MyDrive/Glider data/glider_data.h5
# Head of combined data:
#                   time  latitude  longitude     depth  temperature   salinity  \
# 0  2018-11-13 14:28:33  47.66053 -64.408356  0.396656       4.4046  29.618965
# 1  2018-11-13 14:28:35  47.66053 -64.408348  0.337158       4.4045  29.623238
# 2  2018-11-13 14:28:37  47.66053 -64.408348  0.356990       4.4039  29.612000
# 3  2018-11-13 14:28:39  47.66053 -64.408348  0.446238       4.4033  29.624264
# 4  2018-11-13 14:28:41  47.66053 -64.408348  0.426405       4.4026  29.617865
#
#        density      oxygen
# 0  1023.474670  289.033142
# 1  1023.477783  288.951508
# 2  1023.469055  288.994812
# 3  1023.479248  288.865906
# 4  1023.474121  288.982819

# %% [markdown]
# ## 2) Cluster the data using persistent homology

# %%
def split_large_component(component_indices, points, max_size):
    """
    Given a set of indices for a large connected component,
    split it into smaller clusters so that each resulting cluster has at most max_size points.
    """
    component_indices = np.array(list(component_indices))
    num_points = len(component_indices)
    n_clusters = int(np.ceil(num_points / max_size))
    component_points = points[component_indices]
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    sub_labels = kmeans.fit_predict(component_points)
    new_clusters = []
    for cl in np.unique(sub_labels):
        indices = component_indices[sub_labels == cl]
        new_clusters.append(set(indices))
    return new_clusters

sample_file = os.path.join(data_dir, 'glider_data.h5')
df = pd.read_hdf(sample_file)
print("Initial dataset size:", df.shape[0])

# For the sample, we use 5000 rows
df_sample = df.sample(n=1000, random_state=42)
df_sample = df_sample.dropna()
df_sample = df_sample.drop(columns=['time'], errors='ignore')

# Remove the oxygen column because it is the dependent variable.
if 'oxygen' in df_sample.columns:
    df_sample = df_sample.drop(columns=['oxygen'])

# Select only the features for topology: latitude, longitude, and depth.
# Columns are assumed to be named exactly
required_features = ['latitude', 'longitude', 'depth', 'salinity', 'density', 'temperature']
if not all(col in df_sample.columns for col in required_features):
    raise ValueError(f"One or more required columns {required_features} not found in the sample data.")

df_features = df_sample[required_features]
scaler = StandardScaler()
points = scaler.fit_transform(df_features.values)
n_points = points.shape[0]
print("Number of sample points used for homology:", n_points)

result = ripser(points, maxdim=1)
diagrams = result['dgms']
plot_diagrams(diagrams, show=True)
# Out:
# Initial dataset size: 36047820
# Number of sample points used for homology: 1000

# %%
threshold_input = input("The persistence diagram is displayed.\nEnter connectivity threshold (e.g., 15): ")
try:
    threshold = float(threshold_input)
except ValueError:
    print("Invalid input. Using default threshold of 15")
    threshold = 15
print("Chosen connectivity threshold (epsilon):", threshold)
# Out:
# The persistence diagram is displayed.
# Enter connectivity threshold (e.g., 15): 2
# Chosen connectivity threshold (epsilon): 2.0

# %% [markdown]
# ### Split and cluster components

# %%
dist_matrix = squareform(pdist(points))
G = nx.Graph()
G.add_nodes_from(range(n_points))
for i in range(n_points):
    for j in range(i + 1, n_points):
        if dist_matrix[i, j] <= threshold:
            G.add_edge(i, j)

components = list(nx.connected_components(G))
print("Number of connected components before splitting:", len(components))

max_size = len(df_sample) / 30
new_components = []
for comp in components:
    if len(comp) > max_size:
        split_comps = split_large_component(comp, points, max_size)
        new_components.extend(split_comps)
    else:
        new_components.append(comp)
print("Number of components after splitting:", len(new_components))

labels = np.empty(n_points, dtype=int)
for label, comp in enumerate(new_components):
    for idx in comp:
        labels[idx] = label

# Merge clusters that are very small relative to the median cluster size.
cluster_sizes = np.array([len(comp) for comp in new_components])
median_size = np.median(cluster_sizes)
min_size_threshold = 0.05 * median_size  # Merge clusters smaller than 50% of median size.
print("Median cluster size:", median_size)
print("Merging clusters smaller than:", min_size_threshold)

num_clusters = len(new_components)

# Compute centroids for each cluster (using the sample points)
centroids = np.zeros((num_clusters, points.shape[1]))
for i, comp in enumerate(new_components):
    comp_indices = list(comp)
    centroids[i] = np.mean(points[comp_indices], axis=0)

# For each cluster that is too small, merge it into the nearest cluster (by centroid distance)
for i in range(num_clusters):
    if cluster_sizes[i] < min_size_threshold:
        distances = np.linalg.norm(centroids[i] - centroids, axis=1)
        distances[i] = np.inf  # ignore self-distance
        nearest = np.argmin(distances)
        print(f"Merging small cluster {i} (size {cluster_sizes[i]}) into cluster {nearest} (size {cluster_sizes[nearest]})")
        labels[labels == i] = nearest


# Load and preprocess the full dataset.
df_full = pd.read_hdf(sample_file)
print("Full dataset shape before cleaning:", df_full.shape)
df_full = df_full.dropna()
df_full = df_full.drop(columns=['time'], errors='ignore')
print("Full dataset shape after cleaning:", df_full.shape)

# For cluster assignment, use only latitude, longitude, and depth features.
if not all(col in df_full.columns for col in required_features):
    raise ValueError(f"One or more required columns {required_features} not found in the full dataset.")

df_full_features = df_full[required_features]
full_points = scaler.transform(df_full_features.values)

# Build a nearest neighbor model using the sample points (with topology clusters)
nbrs = NearestNeighbors(n_neighbors=1, algorithm='auto').fit(points)
distances, indices = nbrs.kneighbors(full_points)
distances = distances.flatten()
indices = indices.flatten()

# For each full dataset point, if its nearest sample point is within the threshold,
# assign the corresponding (merged) cluster label; otherwise, mark as noise (-1).
full_labels = np.where(distances <= threshold, labels[indices], -1)
df_full['component_label'] = full_labels

print("Full dataset cluster assignment complete.")
print("Cluster label counts:", dict(zip(*np.unique(full_labels, return_counts=True))))


# Here we use latitude, longitude, and depth for a 3D plot.
df_full_sample = df_full.sample(n=4000, random_state=42)
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(df_full_sample['longitude'], df_full_sample['latitude'], df_full_sample['depth'],
                c=df_full_sample['component_label'], cmap='tab20', s=5)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_zlabel('Depth')
plt.title("3D Point Cloud of Full Dataset by Component")
plt.colorbar(sc, label='Component Label')
plt.show()


unique_clusters = np.unique(full_labels)
unique_clusters = unique_clusters[1:]
count = 0

# Do not include outlier (-1)
for cluster in unique_clusters:
    subset = df_full[df_full['component_label'] == cluster]
    filename = f"component_{count}.h5"
    subset.to_hdf(filename, key='df', mode='w')
    print(f"Saved cluster {cluster} with {len(subset)} points to {filename}")
    destination = f"/content/drive/MyDrive/Glider data/{filename}"
    # !mv "/content/{filename}" "{destination}"
    count += 1
# Out:
# Number of connected components before splitting: 2
# Number of components after splitting: 31
# Median cluster size: 32.0
# Merging clusters smaller than: 1.6
# Merging small cluster 30 (size 1) into cluster 5 (size 21)
# Full dataset shape before cleaning: (36047820, 8)
# Full dataset shape after cleaning: (36047820, 7)
# Full dataset cluster assignment complete.
# Cluster label counts: {np.int64(-1): np.int64(55413), np.int64(0): np.int64(1284501), np.int64(1): np.int64(1283472), np.int64(2): np.int64(396177), np.int64(3): np.int64(1752999), np.int64(4): np.int64(1255635), np.int64(5): np.int64(1085154), np.int64(6): np.int64(1275807), np.int64(7): np.int64(1443084), np.int64(8): np.int64(1000893), np.int64(9): np.int64(1416678), np.int64(10): np.int64(1214745), np.int64(11): np.int64(517560), np.int64(12): np.int64(1563939), np.int64(13): np.int64(761391), np.int64(14): np.int64(2195607), np.int64(15): np.int64(1073568), np.int64(16): np.int64(640323), np.int64(17): np.int64(333794), np.int64(18): np.int64(1239711), np.int64(19): np.int64(1356582), np.int64(20): np.int64(414922), np.int64(21): np.int64(909168), np.int64(22): np.int64(1863465), np.int64(23): np.int64(490881), np.int64(24): np.int64(1617795), np.int64(25): np.int64(2332014), np.int64(26): np.int64(1722684), np.int64(27): np.int64(1033233), np.int64(28): np.int64(1212174), np.int64(29): np.int64(1304451)}
# Saved cluster 0 with 1284501 points to component_0.h5
# Saved cluster 1 with 1283472 points to component_1.h5
# Saved cluster 2 with 396177 points to component_2.h5
# Saved cluster 3 with 1752999 points to component_3.h5
# Saved cluster 4 with 1255635 points to component_4.h5
# Saved cluster 5 with 1085154 points to component_5.h5
# Saved cluster 6 with 1275807 points to component_6.h5
# Saved cluster 7 with 1443084 points to component_7.h5
# Saved cluster 8 with 1000893 points to component_8.h5
# Saved cluster 9 with 1416678 points to component_9.h5
# Saved cluster 10 with 1214745 points to component_10.h5
# Saved cluster 11 with 517560 points to component_11.h5
# Saved cluster 12 with 1563939 points to component_12.h5
# Saved cluster 13 with 761391 points to component_13.h5
# Saved cluster 14 with 2195607 points to component_14.h5
# Saved cluster 15 with 1073568 points to component_15.h5
# Saved cluster 16 with 640323 points to component_16.h5
# Saved cluster 17 with 333794 points to component_17.h5
# Saved cluster 18 with 1239711 points to component_18.h5
# Saved cluster 19 with 1356582 points to component_19.h5
# Saved cluster 20 with 414922 points to component_20.h5
# Saved cluster 21 with 909168 points to component_21.h5
# Saved cluster 22 with 1863465 points to component_22.h5
# Saved cluster 23 with 490881 points to component_23.h5
# Saved cluster 24 with 1617795 points to component_24.h5
# Saved cluster 25 with 2332014 points to component_25.h5
# Saved cluster 26 with 1722684 points to component_26.h5
# Saved cluster 27 with 1033233 points to component_27.h5
# Saved cluster 28 with 1212174 points to component_28.h5
# Saved cluster 29 with 1304451 points to component_29.h5

# %% [markdown]
# ## 3) Bin data using voxels

# %%
num_lon_bins = numbins
num_lat_bins = numbins
num_depth_bins = numbins
num_clusters = len(unique_clusters)


def bin_glider_data(input_file, dim_bins = 10):

    df = pd.read_hdf(input_file)

    # Compute bin edges using np.linspace based on the min and max of each variable
    lon_bins = np.linspace(df['longitude'].min(), df['longitude'].max(), num_lon_bins + 1)
    lat_bins = np.linspace(df['latitude'].min(), df['latitude'].max(), num_lat_bins + 1)
    depth_bins = np.linspace(df['depth'].min(), df['depth'].max(), num_depth_bins + 1)

    # Create new columns that assign each row to a bin index (0-based)
    df['lon_bin'] = pd.cut(df['longitude'], bins=lon_bins, labels=False, include_lowest=True)
    df['lat_bin'] = pd.cut(df['latitude'], bins=lat_bins, labels=False, include_lowest=True)
    df['depth_bin'] = pd.cut(df['depth'], bins=depth_bins, labels=False, include_lowest=True)

    # Create a voxel identifier as a tuple of (lon_bin, lat_bin, depth_bin)
    df['voxel'] = list(zip(df['lon_bin'], df['lat_bin'], df['depth_bin']))

    # Group the data by voxel and compute aggregate statistics, e.g., mean oxygen value
    voxel_grouped = df.groupby('voxel').agg({
        'oxygen': 'mean',
        'longitude': 'mean',
        'latitude': 'mean',
        'depth': 'mean',
        'salinity': 'mean',
        'density': 'mean',
        'temperature': 'mean'
    }).reset_index()


    # Generate output filename
    num_voxels = voxel_grouped.shape[0]
    base_name = os.path.splitext(os.path.basename(input_file))[0]
    output_file = f"{base_name}_binned_{num_voxels}.h5"

    # Save the processed data
    voxel_grouped.to_hdf(output_file, key='data', mode='w')

    print(f"Processed data saved as: {output_file} with {num_voxels} data points")
    return output_file


def process_multiple_files(file_paths, output_directory, dim_bins):
    for input_file in file_paths:

        # Run the binning function for each file
        binned_file = bin_glider_data(input_file, dim_bins)

        # Correct the directory where the file should be saved
        final_binned_file = os.path.join(output_directory, os.path.basename(binned_file))

        # Rename or move the file to the correct directory on Drive
        shutil.move(binned_file, final_binned_file)

        # Print the final saved path
        print(f"Binned data saved as: {final_binned_file}")

        # Check if the file exists at the given path
        if os.path.exists(final_binned_file):
            print(f"The file exists at: {final_binned_file}")
        else:
            print(f"File not found at: {final_binned_file}")


input_files = [f"/content/drive/MyDrive/Glider data/component_{i}.h5" for i in range(num_clusters)]

# Generate folder if it does not exist yet
folder_path = f"/content/drive/My Drive/Glider data/dim_bins{numbins}"
if not os.path.exists(folder_path):
    os.makedirs(folder_path)
    print(f"Folder created at: {folder_path}")
else:
    print(f"Folder already exists: {folder_path}")

# Directory where binned files will be saved
output_directory = f"/content/drive/MyDrive/Glider data/dim_bins{numbins}"

# Call the function to process multiple files
process_multiple_files(input_files, output_directory, numbins)
# Out:
# Folder already exists: /content/drive/My Drive/Glider data/dim_bins100
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_0_binned_36662.h5 with 36662 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_0_binned_36662.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_0_binned_36662.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_1_binned_27379.h5 with 27379 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_1_binned_27379.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_1_binned_27379.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_2_binned_14245.h5 with 14245 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_2_binned_14245.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_2_binned_14245.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_3_binned_31447.h5 with 31447 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_3_binned_31447.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_3_binned_31447.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_4_binned_30786.h5 with 30786 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_4_binned_30786.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_4_binned_30786.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_5_binned_37934.h5 with 37934 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_5_binned_37934.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_5_binned_37934.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_6_binned_33370.h5 with 33370 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_6_binned_33370.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_6_binned_33370.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_7_binned_34360.h5 with 34360 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_7_binned_34360.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_7_binned_34360.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_8_binned_34474.h5 with 34474 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_8_binned_34474.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_8_binned_34474.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_9_binned_40667.h5 with 40667 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_9_binned_40667.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_9_binned_40667.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_10_binned_34260.h5 with 34260 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_10_binned_34260.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_10_binned_34260.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_11_binned_17807.h5 with 17807 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_11_binned_17807.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_11_binned_17807.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_12_binned_33070.h5 with 33070 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_12_binned_33070.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_12_binned_33070.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_13_binned_27191.h5 with 27191 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_13_binned_27191.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_13_binned_27191.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_14_binned_61425.h5 with 61425 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_14_binned_61425.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_14_binned_61425.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_15_binned_41424.h5 with 41424 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_15_binned_41424.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_15_binned_41424.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_16_binned_17708.h5 with 17708 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_16_binned_17708.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_16_binned_17708.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_17_binned_15809.h5 with 15809 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_17_binned_15809.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_17_binned_15809.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_18_binned_27924.h5 with 27924 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_18_binned_27924.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_18_binned_27924.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_19_binned_31106.h5 with 31106 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_19_binned_31106.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_19_binned_31106.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_20_binned_10543.h5 with 10543 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_20_binned_10543.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_20_binned_10543.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_21_binned_22837.h5 with 22837 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_21_binned_22837.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_21_binned_22837.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_22_binned_40520.h5 with 40520 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_22_binned_40520.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_22_binned_40520.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_23_binned_29190.h5 with 29190 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_23_binned_29190.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_23_binned_29190.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_24_binned_45704.h5 with 45704 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_24_binned_45704.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_24_binned_45704.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_25_binned_48629.h5 with 48629 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_25_binned_48629.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_25_binned_48629.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_26_binned_40400.h5 with 40400 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_26_binned_40400.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_26_binned_40400.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_27_binned_26946.h5 with 26946 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_27_binned_26946.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_27_binned_26946.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
# Processed data saved as: component_28_binned_27248.h5 with 27248 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_28_binned_27248.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_28_binned_27248.h5
# Processed data saved as: component_29_binned_32542.h5 with 32542 data points
# Binned data saved as: /content/drive/MyDrive/Glider data/dim_bins100/component_29_binned_32542.h5
# The file exists at: /content/drive/MyDrive/Glider data/dim_bins100/component_29_binned_32542.h5
# <ipython-input-23-193adbb9e135>:40: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['voxel'], dtype='object')]
#
#   voxel_grouped.to_hdf(output_file, key='data', mode='w')
